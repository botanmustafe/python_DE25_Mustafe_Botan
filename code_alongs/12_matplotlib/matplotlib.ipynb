# %% [markdown]
# # Lexture 12 - Matplotlib
# - in this course, focus on the distinction between two ways of writing matplotlib codes
# - in this course, focus on the components of a matplotlib figure

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### The forst approach - functional/matlab style

# %%
plt.figure()
plt.plot(x,f)
plt.title("sin(x)")
plt.xlabel("x")
plt.ylabel("f")
# Out:
# Text(0, 0.5, 'f')

# %% [markdown]
# #### The second approach - OOP

# %%
fig = plt.figure() # create one figure
ax = plt.axes() # On the fifure, create an axe, Gör 4 st för lab 1 (en för varje sekvens) 
ax.plot(x, f) # on the axe, create a plot
ax.set(xlim=(-10,10), ylim=(-5,5), xlabel="x", ylabel="y") # continue modify the axe object

# check out more about the components here: https://matplotlib.org/stable/gallery/showcase/anatomy.html
# Out:
# [(-10.0, 10.0), (-5.0, 5.0), Text(0.5, 0, 'x'), Text(0, 0.5, 'y')]

# %%
# generate data x
x = np.linspace(-5, 5, 100)
x

# %%
# generate data f
f = np.sin(x)
f
