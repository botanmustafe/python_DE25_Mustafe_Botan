# %% [markdown]
# Exploring the module oldcoins

# %%
from oldcoins import OldCoinsStash

stash_ragnar = OldCoinsStash("Ragnar Lothbroke")
stash_ragnar
# Out:
# OldCoinStash(owner='Ragnar Lothbroke')

# %%
stash_ragnar.deposit(riksdaler=10, skilling=100)
stash_ragnar.check_balance()
# Out:
# 'Coins in stash: 30 riksdaler, 840 skilling'

# %%
stash_ragnar.withdraw(20, 300)

# %%
stash_ragnar.check_balance()
# Out:
# 'Coins in stash: 10 riksdaler, 540 skilling'

# %%
stash_bjorn = OldCoinsStash("Björn")
stash_bjorn
stash_bjorn.check_balance()
stash_bjorn.deposit(100, 500)
stash_bjorn.check_balance()
